# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the csv File

# %% [markdown]
# ### df contains:
# id, NAME, host id, host_identity_verified, host name, neighbourhood group, neighbourhood, lat, long, country, country code, instant_bookable, cancellation_policy, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365

# %%
df = pd.read_csv("Airbnb_Open_Data_new.csv")

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        Construction year    price service fee minimum nights  \
# 0                 2020.0    $966        $193            10.0
# 1                 2007.0    $142         $28            30.0
# 2                 2005.0    $620        $124             3.0
# 3                 2005.0    $368         $74            30.0
# 4                 2009.0    $204         $41            10.0
# ...                  ...      ...         ...            ...
# 102594            2003.0    $844        $169             1.0
# 102595            2016.0    $837        $167             1.0
# 102596            2009.0    $988        $198             3.0
# 102597            2015.0    $546        $109             2.0
# 102598            2010.0  $1,032        $206             1.0
#
#         number of reviews last review reviews per month  review rate number  \
# 0                     9.0  10/19/2021              0.21                 4.0
# 1                    45.0   5/21/2022              0.38                 4.0
# 2                     0.0         NaN               NaN                 5.0
# 3                   270.0  07-05-2019              4.64                 4.0
# 4                     9.0  11/19/2018              0.10                 3.0
# ...                   ...         ...               ...                 ...
# 102594                0.0         NaN               NaN                 3.0
# 102595                1.0  07-06-2015              0.02                 2.0
# 102596                0.0         NaN               NaN                 5.0
# 102597                5.0  10-11-2015              0.10                 3.0
# 102598                0.0         NaN               NaN                 3.0
#
#         calculated host listings count availability 365
# 0                                  6.0            286.0
# 1                                  2.0            228.0
# 2                                  1.0            352.0
# 3                                  1.0            322.0
# 4                                  1.0            289.0
# ...                                ...              ...
# 102594                             1.0            227.0
# 102595                             2.0            395.0
# 102596                             1.0            342.0
# 102597                             1.0            386.0
# 102598                             1.0             69.0
#
# [102599 rows x 24 columns]

# %% [markdown]
# # Cleaning and Preprocessing the dataset

# %% [markdown]
# ### 1. Checking datatypes of each columns in the dataset

# %%
print(df.dtypes)
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# dtype: object

# %% [markdown]
# ### 2. Filtering out and displaying only the country with name 'United States'

# %%
df = df[df['country'] == 'United States']

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        Construction year    price service fee minimum nights  \
# 0                 2020.0    $966        $193            10.0
# 1                 2007.0    $142         $28            30.0
# 2                 2005.0    $620        $124             3.0
# 3                 2005.0    $368         $74            30.0
# 4                 2009.0    $204         $41            10.0
# ...                  ...      ...         ...            ...
# 102594            2003.0    $844        $169             1.0
# 102595            2016.0    $837        $167             1.0
# 102596            2009.0    $988        $198             3.0
# 102597            2015.0    $546        $109             2.0
# 102598            2010.0  $1,032        $206             1.0
#
#         number of reviews last review reviews per month  review rate number  \
# 0                     9.0  10/19/2021              0.21                 4.0
# 1                    45.0   5/21/2022              0.38                 4.0
# 2                     0.0         NaN               NaN                 5.0
# 3                   270.0  07-05-2019              4.64                 4.0
# 4                     9.0  11/19/2018              0.10                 3.0
# ...                   ...         ...               ...                 ...
# 102594                0.0         NaN               NaN                 3.0
# 102595                1.0  07-06-2015              0.02                 2.0
# 102596                0.0         NaN               NaN                 5.0
# 102597                5.0  10-11-2015              0.10                 3.0
# 102598                0.0         NaN               NaN                 3.0
#
#         calculated host listings count availability 365
# 0                                  6.0            286.0
# 1                                  2.0            228.0
# 2                                  1.0            352.0
# 3                                  1.0            322.0
# 4                                  1.0            289.0
# ...                                ...              ...
# 102594                             1.0            227.0
# 102595                             2.0            395.0
# 102596                             1.0            342.0
# 102597                             1.0            386.0
# 102598                             1.0             69.0
#
# [102067 rows x 24 columns]

# %% [markdown]
# ### 3. Removing $ sign from 'price' and 'service fee' columns

# %%
df = df.astype({'price': str, 'service fee': str})

# %%
#print(df.dtypes)

# %%
df['price'] = df['price'].str.replace('$', '')

# %%
df['service fee'] = df['service fee'].str.replace('$', '')

# %%
# changing the value to numeric in 'price' and 'service price'

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['service fee'] = pd.to_numeric(df['service fee'], errors='coerce')

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        Construction year  price service fee minimum nights  number of reviews  \
# 0                 2020.0  966.0       193.0           10.0                9.0
# 1                 2007.0  142.0        28.0           30.0               45.0
# 2                 2005.0  620.0       124.0            3.0                0.0
# 3                 2005.0  368.0        74.0           30.0              270.0
# 4                 2009.0  204.0        41.0           10.0                9.0
# ...                  ...    ...         ...            ...                ...
# 102594            2003.0  844.0       169.0            1.0                0.0
# 102595            2016.0  837.0       167.0            1.0                1.0
# 102596            2009.0  988.0       198.0            3.0                0.0
# 102597            2015.0  546.0       109.0            2.0                5.0
# 102598            2010.0    NaN       206.0            1.0                0.0
#
#         last review  reviews per month  review rate number  \
# 0        10/19/2021               0.21                 4.0
# 1         5/21/2022               0.38                 4.0
# 2               NaN                NaN                 5.0
# 3        07-05-2019               4.64                 4.0
# 4        11/19/2018               0.10                 3.0
# ...             ...                ...                 ...
# 102594          NaN                NaN                 3.0
# 102595   07-06-2015               0.02                 2.0
# 102596          NaN                NaN                 5.0
# 102597   10-11-2015               0.10                 3.0
# 102598          NaN                NaN                 3.0
#
#         calculated host listings count availability 365
# 0                                  6.0            286.0
# 1                                  2.0            228.0
# 2                                  1.0            352.0
# 3                                  1.0            322.0
# 4                                  1.0            289.0
# ...                                ...              ...
# 102594                             1.0            227.0
# 102595                             2.0            395.0
# 102596                             1.0            342.0
# 102597                             1.0            386.0
# 102598                             1.0             69.0
#
# [102067 rows x 24 columns]

# %% [markdown]
# ### 4. Changing the datatype of construction year to numeric

# %%
unique_years = df['Construction year'].unique()

# %%
unique_years
# Out:
# array([2020., 2007., 2005., 2009., 2013., 2015., 2004., 2008., 2010.,
#        2019., 2018., 2006., 2016., 2017., 2021., 2003., 2011., 2012.,
#        2022., 2014.,   nan])

# %%
df['Construction year'] = df['Construction year'].fillna(0000)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        Construction year  price service fee minimum nights  number of reviews  \
# 0                 2020.0  966.0       193.0           10.0                9.0
# 1                 2007.0  142.0        28.0           30.0               45.0
# 2                 2005.0  620.0       124.0            3.0                0.0
# 3                 2005.0  368.0        74.0           30.0              270.0
# 4                 2009.0  204.0        41.0           10.0                9.0
# ...                  ...    ...         ...            ...                ...
# 102594            2003.0  844.0       169.0            1.0                0.0
# 102595            2016.0  837.0       167.0            1.0                1.0
# 102596            2009.0  988.0       198.0            3.0                0.0
# 102597            2015.0  546.0       109.0            2.0                5.0
# 102598            2010.0    NaN       206.0            1.0                0.0
#
#         last review  reviews per month  review rate number  \
# 0        10/19/2021               0.21                 4.0
# 1         5/21/2022               0.38                 4.0
# 2               NaN                NaN                 5.0
# 3        07-05-2019               4.64                 4.0
# 4        11/19/2018               0.10                 3.0
# ...             ...                ...                 ...
# 102594          NaN                NaN                 3.0
# 102595   07-06-2015               0.02                 2.0
# 102596          NaN                NaN                 5.0
# 102597   10-11-2015               0.10                 3.0
# 102598          NaN                NaN                 3.0
#
#         calculated host listings count availability 365
# 0                                  6.0            286.0
# 1                                  2.0            228.0
# 2                                  1.0            352.0
# 3                                  1.0            322.0
# 4                                  1.0            289.0
# ...                                ...              ...
# 102594                             1.0            227.0
# 102595                             2.0            395.0
# 102596                             1.0            342.0
# 102597                             1.0            386.0
# 102598                             1.0             69.0
#
# [102067 rows x 24 columns]

# %%
df = df.astype({'Construction year': int})

# %%
print(df.dtypes)
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                   int32
# price                             float64
# service fee                       float64
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# dtype: object

# %% [markdown]
# ### 5. Removing blank values from NAME, price

# %%
df.dropna(subset=['price', 'NAME', 'neighbourhood group', 'neighbourhood'], inplace=True)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 4       92037596077               verified       Lyndon           Manhattan
# 5       45498551794               verified     Michelle           Manhattan
# ...             ...                    ...          ...                 ...
# 102592  53266862889            unconfirmed         Nick           Manhattan
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# 5               Murray Hill  40.74767 -73.97500  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102592              Tribeca  40.71845 -74.01183  United States  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
#
#        Construction year  price service fee minimum nights  number of reviews  \
# 0                   2020  966.0       193.0           10.0                9.0
# 1                   2007  142.0        28.0           30.0               45.0
# 2                   2005  620.0       124.0            3.0                0.0
# 4                   2009  204.0        41.0           10.0                9.0
# 5                   2013  577.0       115.0            3.0               74.0
# ...                  ...    ...         ...            ...                ...
# 102592              2016  787.0       157.0            1.0                0.0
# 102594              2003  844.0       169.0            1.0                0.0
# 102595              2016  837.0       167.0            1.0                1.0
# 102596              2009  988.0       198.0            3.0                0.0
# 102597              2015  546.0       109.0            2.0                5.0
#
#         last review  reviews per month  review rate number  \
# 0        10/19/2021               0.21                 4.0
# 1         5/21/2022               0.38                 4.0
# 2               NaN                NaN                 5.0
# 4        11/19/2018               0.10                 3.0
# 5         6/22/2019               0.59                 3.0
# ...             ...                ...                 ...
# 102592          NaN                NaN                 2.0
# 102594          NaN                NaN                 3.0
# 102595   07-06-2015               0.02                 2.0
# 102596          NaN                NaN                 5.0
# 102597   10-11-2015               0.10                 3.0
#
#         calculated host listings count availability 365
# 0                                  6.0            286.0
# 1                                  2.0            228.0
# 2                                  1.0            352.0
# 4                                  1.0            289.0
# 5                                  1.0            374.0
# ...                                ...              ...
# 102592                             1.0            177.0
# 102594                             1.0            227.0
# 102595                             2.0            395.0
# 102596                             1.0            342.0
# 102597                             1.0            386.0
#
# [83771 rows x 24 columns]

# %% [markdown]
# ### 6. Replacing nan values to unconfirmed in host_identity_verified

# %%
df['host_identity_verified'] = df['host_identity_verified'].fillna('unconfirmed')

# %% [markdown]
# ### 7. Replacing nan values to Not Available in host name

# %%
df['host name'] = df['host name'].fillna('Not Available')

# %% [markdown]
# ### 8. Replacing nan values to US in country code, and United States in country

# %%
df['country code'] = df['country code'].fillna('US')
df['country'] = df['country'].fillna('United States')

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556            unconfirmed        Elise           Manhattan
# 4       92037596077               verified       Lyndon           Manhattan
# 5       45498551794               verified     Michelle           Manhattan
# ...             ...                    ...          ...                 ...
# 102592  53266862889            unconfirmed         Nick           Manhattan
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# 5               Murray Hill  40.74767 -73.97500  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102592              Tribeca  40.71845 -74.01183  United States  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
#
#        Construction year  price service fee minimum nights  number of reviews  \
# 0                   2020  966.0       193.0           10.0                9.0
# 1                   2007  142.0        28.0           30.0               45.0
# 2                   2005  620.0       124.0            3.0                0.0
# 4                   2009  204.0        41.0           10.0                9.0
# 5                   2013  577.0       115.0            3.0               74.0
# ...                  ...    ...         ...            ...                ...
# 102592              2016  787.0       157.0            1.0                0.0
# 102594              2003  844.0       169.0            1.0                0.0
# 102595              2016  837.0       167.0            1.0                1.0
# 102596              2009  988.0       198.0            3.0                0.0
# 102597              2015  546.0       109.0            2.0                5.0
#
#         last review  reviews per month  review rate number  \
# 0        10/19/2021               0.21                 4.0
# 1         5/21/2022               0.38                 4.0
# 2               NaN                NaN                 5.0
# 4        11/19/2018               0.10                 3.0
# 5         6/22/2019               0.59                 3.0
# ...             ...                ...                 ...
# 102592          NaN                NaN                 2.0
# 102594          NaN                NaN                 3.0
# 102595   07-06-2015               0.02                 2.0
# 102596          NaN                NaN                 5.0
# 102597   10-11-2015               0.10                 3.0
#
#         calculated host listings count availability 365
# 0                                  6.0            286.0
# 1                                  2.0            228.0
# 2                                  1.0            352.0
# 4                                  1.0            289.0
# 5                                  1.0            374.0
# ...                                ...              ...
# 102592                             1.0            177.0
# 102594                             1.0            227.0
# 102595                             2.0            395.0
# 102596                             1.0            342.0
# 102597                             1.0            386.0
#
# [83771 rows x 24 columns]

# %% [markdown]
# ### 9. Replacing nan values to 0 in service fee, 0 in minimum nights, 0 in number of reviews, 0 in reviews per month, 0 in review rate number, 0 in calculated host listings count, 0 in availability 365

# %%
df['service fee'] = df['service fee'].fillna(0)
df['minimum nights'] = df['minimum nights'].fillna(0)
df['number of reviews'] = df['number of reviews'].fillna(0)
df['reviews per month'] = df['reviews per month'].fillna(0)
df['review rate number'] = df['review rate number'].fillna(0)
df['calculated host listings count'] = df['calculated host listings count'].fillna(0)
df['availability 365'] = df['availability 365'].fillna(0)

# %%
df['instant_bookable'] = df['instant_bookable'].replace('TRUE', 'True')
df['instant_bookable'] = df['instant_bookable'].replace('FALSE', 'False')
df['instant_bookable'] = df['instant_bookable'].fillna('False')

# %%
#Changing the datatype

# %%
df = df.astype({'availability 365': int, 'calculated host listings count':int, 'review rate number': int, 'number of reviews': int, 'minimum nights': int })

# %%
print(df.dtypes)
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                   int32
# price                             float64
# service fee                       float64
# minimum nights                      int32
# number of reviews                   int32
# last review                        object
# reviews per month                 float64
# review rate number                  int32
# calculated host listings count      int32
# availability 365                    int32
# dtype: object

# %% [markdown]
# ### 10. Last review date is not required for the analysis, so I am deleting the column

# %%
del df['last review']

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556            unconfirmed        Elise           Manhattan
# 4       92037596077               verified       Lyndon           Manhattan
# 5       45498551794               verified     Michelle           Manhattan
# ...             ...                    ...          ...                 ...
# 102592  53266862889            unconfirmed         Nick           Manhattan
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# 5               Murray Hill  40.74767 -73.97500  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102592              Tribeca  40.71845 -74.01183  United States  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
#
#               room type Construction year  price service fee  minimum nights  \
# 0          Private room              2020  966.0       193.0              10
# 1       Entire home/apt              2007  142.0        28.0              30
# 2          Private room              2005  620.0       124.0               3
# 4       Entire home/apt              2009  204.0        41.0              10
# 5       Entire home/apt              2013  577.0       115.0               3
# ...                 ...               ...    ...         ...             ...
# 102592  Entire home/apt              2016  787.0       157.0               1
# 102594     Private room              2003  844.0       169.0               1
# 102595     Private room              2016  837.0       167.0               1
# 102596     Private room              2009  988.0       198.0               3
# 102597  Entire home/apt              2015  546.0       109.0               2
#
#         number of reviews  reviews per month  review rate number  \
# 0                       9               0.21                   4
# 1                      45               0.38                   4
# 2                       0               0.00                   5
# 4                       9               0.10                   3
# 5                      74               0.59                   3
# ...                   ...                ...                 ...
# 102592                  0               0.00                   2
# 102594                  0               0.00                   3
# 102595                  1               0.02                   2
# 102596                  0               0.00                   5
# 102597                  5               0.10                   3
#
#         calculated host listings count  availability 365
# 0                                    6               286
# 1                                    2               228
# 2                                    1               352
# 4                                    1               289
# 5                                    1               374
# ...                                ...               ...
# 102592                               1               177
# 102594                               1               227
# 102595                               2               395
# 102596                               1               342
# 102597                               1               386
#
# [83771 rows x 23 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
descriptive_stats = df[['price', 'minimum nights', 'number of reviews', 'reviews per month', 'availability 365']].describe()
print(descriptive_stats)
# Out:
#               price  minimum nights  number of reviews  reviews per month  \
# count  83771.000000    83771.000000       83771.000000       83771.000000
# mean     524.727853        8.059889          27.289718           1.156603
# std      273.454617       29.539345          49.261114           1.676523
# min       50.000000     -365.000000           0.000000           0.000000
# 25%      288.000000        1.000000           1.000000           0.090000
# 50%      524.000000        3.000000           7.000000           0.480000
# 75%      759.000000        5.000000          30.000000           1.700000
# max      999.000000     5645.000000        1024.000000          90.000000
#
#        availability 365
# count      83771.000000
# mean         140.553640
# std          135.085082
# min          -10.000000
# 25%            3.000000
# 50%           95.000000
# 75%          268.000000
# max          426.000000

# %%
correlation_matrix = df[['price', 'minimum nights', 'number of reviews', 'reviews per month', 'availability 365']].corr()
print(correlation_matrix)
# Out:
#                       price  minimum nights  number of reviews  \
# price              1.000000       -0.004564           0.004466
# minimum nights    -0.004564        1.000000          -0.050142
# number of reviews  0.004466       -0.050142           1.000000
# reviews per month  0.000613       -0.093123           0.618985
# availability 365  -0.004766        0.060358           0.096945
#
#                    reviews per month  availability 365
# price                       0.000613         -0.004766
# minimum nights             -0.093123          0.060358
# number of reviews           0.618985          0.096945
# reviews per month           1.000000          0.071433
# availability 365            0.071433          1.000000

# %% [markdown]
# ### 1. Count of hotels according to rating

# %%
star_ratings_count = df['review rate number'].value_counts().sort_index()
print("Number of hotel by star rating:")
for rating, count in star_ratings_count.items():
    print(f"{rating} star rating: {count} hotels")
# Out:
# Number of hotel by star rating:
# 0 star rating: 264 hotels
# 1 star rating: 7429 hotels
# 2 star rating: 18839 hotels
# 3 star rating: 18921 hotels
# 4 star rating: 19086 hotels
# 5 star rating: 19232 hotels

# %% [markdown]
# ### 2.Top 10 count of hotels rated 5 star by most people

# %%
five_star_hotels = df[df['review rate number'] == 5]
top_five_star_hotels = five_star_hotels.sort_values(by = 'number of reviews', ascending = False)
print("Top 5-star rated hotels by number of reviews:")
print(top_five_star_hotels[['id', 'NAME', 'number of reviews', 'neighbourhood']].head(10))
# Out:
# Top 5-star rated hotels by number of reviews:
#               id                                               NAME  \
# 53823   30727779                                         City Queen
# 13496    8455177                            Room Near JFK Twin Beds
# 49915   28569391  Private Room in Spacious Quiet Apt., Elevator ...
# 54327   31006138                         Private room mins from JFK
# 49738   28471633                   My Little Guest Room in Flushing
# 77568   43842142  Cozy Room Family Home LGA Airport NO CLEANING FEE
# 90226   50833156  Cozy Room Family Home LGA Airport NO CLEANING FEE
# 20404   12270465  Cozy Room Family Home LGA Airport NO CLEANING FEE
# 100491  56502515  Cozy Room Family Home LGA Airport NO CLEANING FEE
# 54268   30973552  Victorian Private Brownstone Apartment & Backyard
#
#         number of reviews  neighbourhood
# 53823                 583           SoHo
# 13496                 576        Jamaica
# 49915                 567         Harlem
# 54327                 563        Jamaica
# 49738                 550       Flushing
# 77568                 510  East Elmhurst
# 90226                 510  East Elmhurst
# 20404                 510  East Elmhurst
# 100491                510  East Elmhurst
# 54268                 491   Clinton Hill

# %% [markdown]
# ### 3. From 2018 to 2022 yearwise highest and lowest priced room

# %%
filtered_df = df[(df['Construction year'] >= 2018) & (df['Construction year'] <= 2022)]
max_priced_rooms = filtered_df.groupby('Construction year')['price'].max().sort_index(ascending=False)
min_priced_rooms = filtered_df.groupby('Construction year')['price'].min().sort_index(ascending=False)

print("Maximum priced room yearwise: ", max_priced_rooms)
print("Minimum priced room yearwise: ", min_priced_rooms)
# Out:
# Maximum priced room yearwise:  Construction year
# 2022    999.0
# 2021    999.0
# 2020    999.0
# 2019    999.0
# 2018    999.0
# Name: price, dtype: float64
# Minimum priced room yearwise:  Construction year
# 2022    50.0
# 2021    50.0
# 2020    50.0
# 2019    50.0
# 2018    50.0
# Name: price, dtype: float64

# %% [markdown]
# ### 4. Total number of listings that each host has across all their properties

# %%
host_listings_count = df.groupby('host id')['calculated host listings count'].sum()

# %%
#host_listings_count

# %%
host_listings_count.head()
# Out:
# host id
# 123600518    1
# 124039648    1
# 124472619    2
# 130349612    1
# 130593431    1
# Name: calculated host listings count, dtype: int32

# %% [markdown]
# ### 5. Average pricing of different room types and average number of review

# %%
average_price_by_room_type = df.groupby('room type')[['price', 'number of reviews']].mean()
average_price_by_room_type
# Out:
#                       price  number of reviews
# room type
# Entire home/apt  524.941396          27.257117
# Hotel room       576.431579          84.031579
# Private room     524.296387          27.523009
# Shared room      525.925155          20.068655

# %% [markdown]
# ### 6. Booking Policy and Cancellation Policy

# %%
instant_bookable_counts = df['instant_bookable'].value_counts()
calcellation_policy_counts = df['cancellation_policy'].value_counts()

# %%
print(instant_bookable_counts)
print(calcellation_policy_counts)
# Out:
# instant_bookable
# False    42008
# True     41741
# False       22
# Name: count, dtype: int64
# cancellation_policy
# moderate    28067
# strict      27879
# flexible    27825
# Name: count, dtype: int64

# %% [markdown]
# # Visualization of the analysis of the dataset

# %% [markdown]
# ### 1. Price Distribution

# %%
plt.hist(df['price'], bins=30, color='lightyellow', edgecolor='black')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 2.Room Type Distribution

# %%
room_type_counts = df['room type'].value_counts()
room_type_counts.plot(kind='bar', color='lightgreen')
plt.title('Room Type Distribution')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 3. Average Price by Room Type

# %%
avg_price_by_room_type = df.groupby('room type')[['price']].mean()
avg_price_by_room_type.plot(kind = 'bar')
plt.title('Average Price by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ### 4. Count of Hotels by Construction Year

# %%
filtered_df = df[df['Construction year']!= 0]
construction_year_counts = filtered_df['Construction year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
construction_year_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Count of Hotels by Construction Year')
plt.xlabel('Construction Year')
plt.ylabel('Count of Hotels')
plt.show()

# %% [markdown]
# ### 5. Top 10 Number of Listings in Neighbourhood

# %%
neighbourhood_counts = df['neighbourhood'].value_counts()
top_10_neighbourhood = neighbourhood_counts.head(10)
top_10_neighbourhood.plot(kind = 'bar', figsize=(10, 6), color='grey')
plt.title('Top 10 Number of Listings in Neighbourhood')
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 6. Number of Reviews vs. Price

# %%
plt.scatter(df['number of reviews'], df['price'], color='orange', alpha=0.5)
plt.title('Number of Reviews vs. Price')
plt.xlabel('Number of Reviews')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # Exporting the cleaned dataset as CSV file

# %%
df.to_csv('cleaned_dataset.csv')
